# %%
import importlib

# %%
import MakeGaseousCluster
importlib.reload(MakeGaseousCluster)
# Out:
# <module 'MakeGaseousCluster' from '/fs/lustre/scratch/RAID-CITA/yanlong/bbh/MakeGaseousCluster/MakeGaseousCluster.py'>

# %%
MakeGaseousCluster.MakeGaseousCluster(debug=True)
# Out:
# G = 43070.92201641046
# Making CMC IC
# Evaluating profile interpolators
# /fs/lustre/cita/yanlong/anaconda3/lib/python3.11/site-packages/galpy/df/kingdf.py:185: RuntimeWarning: invalid value encountered in sqrt
#   sqW = numpy.sqrt(W)
#
# /fs/lustre/scratch/RAID-CITA/yanlong/bbh/MakeGaseousCluster/utils.py:59: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(integral / rho_x)
# Setting stars
#  (2T+U)/U = -0
# Setting gas
# Doing refinement
# Loaded 16777216 (~256^3) particles
# Setting gas velocity
# Setting gas magnetic field
# Shape: (320, 320, 320)
# Applying normalization.
# Done!
# PartType0
#   Masses
#   Coordinates
#   ParticleIDs
#   InternalEnergy
#   Velocities
#   MagneticField
# PartType5
#   Masses
#   Coordinates
#   Velocities
#   ParticleIDs
#   ProtoStellarStage
